# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs, make_circles
from sklearn.model_selection import train_test_split

# %%
X, y = make_circles(n_samples=1000, factor=0.3, noise=0.2, random_state=1)

# %% [markdown]
# Here we use a routine provided by sklearn for splitting the dataset.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %% [markdown]
# ## Plot data
#
# It is always a good first step to plot the data to get some visual insights.

# %%
fig = plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:,1], c=y)

# %% [markdown]
# Similar, we can also plot the train or test data.

# %%
fig = plt.figure(figsize=(6,6))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train)

# %% [markdown]
# # Pytorch

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Step 0: Load models for random dynamical systems

# %%
def PM_map(x, gamma=0.7):
  if x < 0.5:
    return x*(1+(2**gamma)*(x**gamma))
  else:
    return 2*x-1

def Thaler_map(x, gamma=0.6):
  return (x*(1+(x/(1+x))**(gamma-1) - x**(gamma-1))**(1/(1-gamma))) % 1

# %%
#visualization
PM_iters = []
x = (0.1)**(0.7)
PM_iters.append(x)
for i in range(1001):
  x = PM_map(x,0.7)
  PM_iters.append(x)
  
plt.plot(PM_iters)
plt.title('PM map')
plt.show()

thaler_iters = []
x = (0.1)**(0.6)
thaler_iters.append(x)
for i in range(1001):
  x = Thaler_map(x)
  thaler_iters.append(x)

plt.plot(thaler_iters)
plt.title('Thaler map')
plt.show()

#print(np.mean(thaler_iters))
#print(np.mean(PM_iters))

# %% [markdown]
# ### Step 1: Create a torch data loader

# %%
BATCH_SIZE = 500 #equal training set size

# %%
dataset = torch.utils.data.TensorDataset(
    torch.tensor(X_train, dtype=torch.float),
    torch.tensor(y_train, dtype=torch.float).reshape(-1,1))

train_loader = torch.utils.data.DataLoader(dataset,batch_size=BATCH_SIZE)
test_target = torch.tensor(y_test, dtype=torch.float).reshape(-1,1)

# %% [markdown]
# ### Step 2: Build a Network

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(2, 32)  # input layer
        self.fc2 = nn.Linear(32, 32) # hidden layer
        self.fc3 = nn.Linear(32, 1)  # ouput layer
        
        self.layers = [self.fc1, self.fc2]

    def forward(self, x):
        
        for i, layer in enumerate(self.layers):
            x = layer(x)
            x = F.relu(x)
        x = torch.sigmoid(self.fc3(x))
        return x

# %% [markdown]
# ### Step 4: Train the Model

# %%
def train(lr=0.1, epochs=100, option=0):
    
    np.random.seed(1)
    torch.manual_seed(1)
    torch.cuda.manual_seed(1)
    torch.cuda.manual_seed_all(1)
    
    if option == 0 or option == -1:
      r = 0.0
    elif option == 1:
      gamma = 0.7
      r = (0.1)**gamma
    elif option == 2:
      gamma = 0.6
      r = (0.1)**gamma
    

    net = Net()
    print(net)

    """Train for one epoch."""
    net.train()

    optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.0) 
                #optim.AdamW(net.parameters(), lr=lr, weight_decay=0.0001)

    criterion = nn.BCELoss() # Sigmoid layer + Binary Cross Entropy

    train_loss_hist = []
    test_loss_hist = []
    train_acc_hist = []
    test_acc_hist = []
    #count = 0

    for epoch in range(1, epochs):
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            outputs = net(inputs)      

            if option == 0:
                reg = 0.0
                loss = criterion(outputs, targets)  
            elif option == -1:
                reg = 0.0
                for param in net.parameters():
                    reg += 0.001 * (param ** 2).sum()
                loss = criterion(outputs, targets) + reg
            else:
                reg = 0.0
                for param in net.parameters():
                    reg += 0.01 * (param ** 2).sum()
                loss = criterion(outputs, targets) + r * reg #/(1+0.02*count)
                if option == 1:
                    r = PM_map(r,gamma=gamma)
                elif option == 2:
                    r = Thaler_map(r,gamma=gamma)
                else:
                    print('Invalid option!')
                #count += 1  


            loss.backward()        
            optimizer.step()
            optimizer.zero_grad()
            
        #evaluate
        net.eval()
        y_pred = net(torch.from_numpy(X_test).float())
        test_loss = criterion(y_pred, test_target) + r * reg
        y_pred = y_pred.detach().numpy()
        y_pred[y_pred>=0.5] = 1.0
        y_pred[y_pred<0.5] = 0.0

        train_loss_hist.append(loss)
        test_loss_hist.append(test_loss)
        test_acc_hist.append(accuracy_score(y_test, y_pred))

        if epoch % 50 == 0: print('Epoch: %s, Train loss: %s', (epoch, train_loss_hist[-1]))
        if epoch % 50 == 0: print('Epoch: %s, Test loss: %s', (epoch, test_loss_hist[-1]))
        if epoch % 50 == 0: print('Epoch: %s, Test accuracy: %s', (epoch, test_acc_hist[-1]))
    
    plt.plot(train_loss_hist)
    plt.ylabel('train loss', fontsize=20)
    plt.xlabel('epoch', fontsize=20)
    plt.show()
    
    plt.plot(test_loss_hist)
    plt.ylabel('test loss', fontsize=20)
    plt.xlabel('epoch', fontsize=20)
    plt.show()

    plt.plot(test_acc_hist)
    plt.ylabel('test accuracy', fontsize=20)
    plt.xlabel('epoch', fontsize=20)
    plt.show()

    return net

# %%
def evaluate(net):
    net.eval()
    y_pred = net(torch.from_numpy(X_test).float())
    y_pred = y_pred.detach().numpy()
    y_pred[y_pred>=0.5] = 1.0
    y_pred[y_pred<0.5] = 0.0

    from sklearn.metrics import accuracy_score
    print('Test acc: ', accuracy_score(y_test, y_pred))

# %%
def plot(net, name='baseline'):
   # Adding decision boundary to plot
    x1 = np.arange(-1.8, 1.8, 0.1)
    x2 = np.arange(-1.8, 1.8, 0.1)
    Z = np.zeros((len(x1),len(x2)))
    net.eval()
    for i in range(len(x1)):
        for j in range(len(x2)):
            pred = net(torch.from_numpy(np.array([x1[i], x2[j]]).reshape(1, -1)).float())
            pred = pred.detach().numpy()
            Z[i,j] = pred 
        
    fig = plt.figure(figsize=(6,5))
    colors = np.array(['#2b8cbe','#31a354'])
    plt.contourf(x1, x2, Z.T, alpha=0.4, vmin=0, vmax=1, cmap='PuRd')
    #plt.colorbar()
    plt.scatter(X[:,0], X[:,1], c=colors[y], alpha=0.5)
    plt.ylim(-1.4,1.4)
    plt.xlim(-1.4,1.4)
    plt.axis('off')
    plt.tight_layout()
    #plt.savefig('toy_'+name+'.pdf')

# %% [markdown]
# # Baseline

# %%
net = train(lr=0.1, epochs=1000)

evaluate(net)
plot(net, name='baseline')
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
# )
# Epoch: %s, Train loss: %s (50, tensor(0.6772, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (50, tensor(0.6771, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (50, 0.648)
# Epoch: %s, Train loss: %s (100, tensor(0.6491, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (100, tensor(0.6489, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (100, 0.836)
# Epoch: %s, Train loss: %s (150, tensor(0.5932, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (150, tensor(0.5925, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (150, 0.914)
# Epoch: %s, Train loss: %s (200, tensor(0.4893, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (200, tensor(0.4874, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (200, 0.948)
# Epoch: %s, Train loss: %s (250, tensor(0.3455, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (250, tensor(0.3458, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (250, 0.95)
# Epoch: %s, Train loss: %s (300, tensor(0.2357, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (300, tensor(0.2412, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (300, 0.95)
# Epoch: %s, Train loss: %s (350, tensor(0.1785, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (350, tensor(0.1888, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (350, 0.948)
# Epoch: %s, Train loss: %s (400, tensor(0.1504, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (400, tensor(0.1644, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (400, 0.948)
# Epoch: %s, Train loss: %s (450, tensor(0.1352, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (450, tensor(0.1525, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (450, 0.948)
# Epoch: %s, Train loss: %s (500, tensor(0.1259, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (500, tensor(0.1459, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (500, 0.948)
# Epoch: %s, Train loss: %s (550, tensor(0.1197, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (550, tensor(0.1424, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (550, 0.948)
# Epoch: %s, Train loss: %s (600, tensor(0.1154, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (600, tensor(0.1406, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (600, 0.946)
# Epoch: %s, Train loss: %s (650, tensor(0.1123, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (650, tensor(0.1396, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (650, 0.946)
# Epoch: %s, Train loss: %s (700, tensor(0.1100, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (700, tensor(0.1390, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (700, 0.946)
# Epoch: %s, Train loss: %s (750, tensor(0.1082, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (750, tensor(0.1386, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (750, 0.946)
# Epoch: %s, Train loss: %s (800, tensor(0.1068, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (800, tensor(0.1385, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (800, 0.946)
# Epoch: %s, Train loss: %s (850, tensor(0.1056, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (850, tensor(0.1385, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (850, 0.946)
# Epoch: %s, Train loss: %s (900, tensor(0.1046, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (900, tensor(0.1386, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (900, 0.946)
# Epoch: %s, Train loss: %s (950, tensor(0.1039, grad_fn=<BinaryCrossEntropyBackward0>))
# Epoch: %s, Test loss: %s (950, tensor(0.1390, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (950, 0.946)
# Test acc:  0.946

# %% [markdown]
# # Option 1: PM map

# %%
net = train(lr=0.1, epochs=1000, option=1)

evaluate(net)
plot(net, name='with PM map')
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
# )
# Epoch: %s, Train loss: %s (50, tensor(0.6780, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (50, tensor(0.6780, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (50, 0.642)
# Epoch: %s, Train loss: %s (100, tensor(0.6540, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (100, tensor(0.6542, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (100, 0.836)
# Epoch: %s, Train loss: %s (150, tensor(0.8484, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (150, tensor(0.8276, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (150, 0.914)
# Epoch: %s, Train loss: %s (200, tensor(0.5748, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (200, tensor(0.6040, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (200, 0.948)
# Epoch: %s, Train loss: %s (250, tensor(0.5998, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (250, tensor(0.4897, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (250, 0.946)
# Epoch: %s, Train loss: %s (300, tensor(0.4653, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (300, tensor(0.6300, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (300, 0.95)
# Epoch: %s, Train loss: %s (350, tensor(0.3023, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (350, tensor(0.3411, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (350, 0.95)
# Epoch: %s, Train loss: %s (400, tensor(0.2334, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (400, tensor(0.2551, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (400, 0.948)
# Epoch: %s, Train loss: %s (450, tensor(0.4313, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (450, tensor(0.2991, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (450, 0.948)
# Epoch: %s, Train loss: %s (500, tensor(0.2646, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (500, tensor(0.3431, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (500, 0.948)
# Epoch: %s, Train loss: %s (550, tensor(0.4237, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (550, tensor(0.2970, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (550, 0.948)
# Epoch: %s, Train loss: %s (600, tensor(0.4238, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (600, tensor(0.2923, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (600, 0.948)
# Epoch: %s, Train loss: %s (650, tensor(0.2280, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (650, tensor(0.2933, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (650, 0.948)
# Epoch: %s, Train loss: %s (700, tensor(0.1478, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (700, tensor(0.1651, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (700, 0.948)
# Epoch: %s, Train loss: %s (750, tensor(0.1353, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (750, tensor(0.1532, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (750, 0.948)
# Epoch: %s, Train loss: %s (800, tensor(0.1394, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (800, tensor(0.1623, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (800, 0.948)
# Epoch: %s, Train loss: %s (850, tensor(0.1876, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (850, tensor(0.2323, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (850, 0.948)
# Epoch: %s, Train loss: %s (900, tensor(0.3237, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (900, tensor(0.5255, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (900, 0.948)
# Epoch: %s, Train loss: %s (950, tensor(0.3336, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (950, tensor(0.5524, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (950, 0.948)
# Test acc:  0.948

# %% [markdown]
# # Option 2: Thaler map

# %%
net = train(lr=0.1, epochs=1000, option=2)

evaluate(net)
plot(net, name='with Thaler map')
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
# )
# Epoch: %s, Train loss: %s (50, tensor(0.8193, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (50, tensor(0.9225, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (50, 0.646)
# Epoch: %s, Train loss: %s (100, tensor(0.8387, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (100, tensor(0.7547, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (100, 0.844)
# Epoch: %s, Train loss: %s (150, tensor(0.6385, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (150, tensor(0.6439, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (150, 0.908)
# Epoch: %s, Train loss: %s (200, tensor(0.7872, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (200, tensor(0.7736, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (200, 0.942)
# Epoch: %s, Train loss: %s (250, tensor(0.5288, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (250, tensor(0.5776, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (250, 0.952)
# Epoch: %s, Train loss: %s (300, tensor(0.5715, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (300, tensor(0.4817, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (300, 0.948)
# Epoch: %s, Train loss: %s (350, tensor(0.3633, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (350, tensor(0.4369, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (350, 0.95)
# Epoch: %s, Train loss: %s (400, tensor(0.2335, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (400, tensor(0.2527, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (400, 0.948)
# Epoch: %s, Train loss: %s (450, tensor(0.3907, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (450, tensor(0.5542, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (450, 0.948)
# Epoch: %s, Train loss: %s (500, tensor(0.4340, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (500, tensor(0.2750, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (500, 0.948)
# Epoch: %s, Train loss: %s (550, tensor(0.2418, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (550, tensor(0.2886, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (550, 0.948)
# Epoch: %s, Train loss: %s (600, tensor(0.3455, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (600, tensor(0.4956, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (600, 0.948)
# Epoch: %s, Train loss: %s (650, tensor(0.4116, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (650, tensor(0.2306, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (650, 0.948)
# Epoch: %s, Train loss: %s (700, tensor(0.1971, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (700, tensor(0.2323, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (700, 0.948)
# Epoch: %s, Train loss: %s (750, tensor(0.5403, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (750, tensor(0.5447, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (750, 0.948)
# Epoch: %s, Train loss: %s (800, tensor(0.4016, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (800, tensor(0.2217, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (800, 0.948)
# Epoch: %s, Train loss: %s (850, tensor(0.1520, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (850, tensor(0.1706, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (850, 0.948)
# Epoch: %s, Train loss: %s (900, tensor(0.1749, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (900, tensor(0.2021, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (900, 0.948)
# Epoch: %s, Train loss: %s (950, tensor(0.1588, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (950, tensor(0.1811, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (950, 0.948)
# Test acc:  0.948

# %% [markdown]
# # With Standard Regularization

# %%
net = train(lr=0.1, epochs=1000, option=-1)

evaluate(net)
plot(net, name='with standard regularization')
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
# )
# Epoch: %s, Train loss: %s (50, tensor(0.7032, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (50, tensor(0.6777, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (50, 0.644)
# Epoch: %s, Train loss: %s (100, tensor(0.6776, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (100, tensor(0.6517, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (100, 0.836)
# Epoch: %s, Train loss: %s (150, tensor(0.6290, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (150, tensor(0.6016, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (150, 0.914)
# Epoch: %s, Train loss: %s (200, tensor(0.5398, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (200, tensor(0.5086, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (200, 0.95)
# Epoch: %s, Train loss: %s (250, tensor(0.4098, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (250, tensor(0.3752, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (250, 0.948)
# Epoch: %s, Train loss: %s (300, tensor(0.2997, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (300, tensor(0.2643, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (300, 0.948)
# Epoch: %s, Train loss: %s (350, tensor(0.2392, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (350, tensor(0.2039, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (350, 0.948)
# Epoch: %s, Train loss: %s (400, tensor(0.2101, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (400, tensor(0.1748, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (400, 0.948)
# Epoch: %s, Train loss: %s (450, tensor(0.1948, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (450, tensor(0.1598, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (450, 0.948)
# Epoch: %s, Train loss: %s (500, tensor(0.1861, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (500, tensor(0.1519, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (500, 0.948)
# Epoch: %s, Train loss: %s (550, tensor(0.1807, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (550, tensor(0.1474, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (550, 0.948)
# Epoch: %s, Train loss: %s (600, tensor(0.1771, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (600, tensor(0.1447, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (600, 0.948)
# Epoch: %s, Train loss: %s (650, tensor(0.1744, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (650, tensor(0.1428, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (650, 0.948)
# Epoch: %s, Train loss: %s (700, tensor(0.1725, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (700, tensor(0.1414, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (700, 0.948)
# Epoch: %s, Train loss: %s (750, tensor(0.1711, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (750, tensor(0.1404, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (750, 0.948)
# Epoch: %s, Train loss: %s (800, tensor(0.1698, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (800, tensor(0.1397, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (800, 0.946)
# Epoch: %s, Train loss: %s (850, tensor(0.1689, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (850, tensor(0.1394, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (850, 0.946)
# Epoch: %s, Train loss: %s (900, tensor(0.1682, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (900, tensor(0.1391, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (900, 0.946)
# Epoch: %s, Train loss: %s (950, tensor(0.1675, grad_fn=<AddBackward0>))
# Epoch: %s, Test loss: %s (950, tensor(0.1389, grad_fn=<AddBackward0>))
# Epoch: %s, Test accuracy: %s (950, 0.946)
# Test acc:  0.946
